# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("zomato.csv")

# %%
df.head()
# Out:
#   Restaurant_Name  Dining_Rating  Delivery_Rating  Dining Votes  \
# 0      Doner King            3.9              4.2            39
# 1      Doner King            3.9              4.2            39
# 2      Doner King            3.9              4.2            39
# 3      Doner King            3.9              4.2            39
# 4      Doner King            3.9              4.2            39
#
#    Delivery_Votes   Cuisine  Place_Name        City                 Item_Name  \
# 0               0  Fast Food   Malakpet   Hyderabad       Platter Kebab Combo
# 1               0  Fast Food   Malakpet   Hyderabad   Chicken Rumali Shawarma
# 2               0  Fast Food   Malakpet   Hyderabad    Chicken Tandoori Salad
# 3               0  Fast Food   Malakpet   Hyderabad         Chicken BBQ Salad
# 4               0  Fast Food   Malakpet   Hyderabad  Special Doner Wrap Combo
#
#   Best_Seller  Votes  Prices
# 0  BESTSELLER     84   249.0
# 1  BESTSELLER     45   129.0
# ...

# %%
print("Rows = ",df.shape[0])
# Out:
# Rows =  123657

# %%
print("Columns = ",df.shape[1])
# Out:
# Columns =  12

# %%
print("Unique Restaurant Names = ", df["Restaurant_Name"].nunique())
# Out:
# Unique Restaurant Names =  826

# %%
print("Unique Restaurant Names = ", df["City"].nunique())
# Out:
# Unique Restaurant Names =  17

# %%
print("Unique Restaurant Names = ", df["Place_Name"].nunique())
# Out:
# Unique Restaurant Names =  324

# %%
df.columns
# Out:
# Index(['Restaurant_Name', 'Dining_Rating', 'Delivery_Rating', 'Dining Votes',
#        'Delivery_Votes', 'Cuisine ', 'Place_Name', 'City', 'Item_Name',
#        'Best_Seller', 'Votes', 'Prices'],
#       dtype='object')

# %%
print("Unique Restaurant Names = ", df["Cuisine "].nunique())
# Out:
# Unique Restaurant Names =  48

# %%
print("Unique Restaurant Names = ", df["Item_Name"].nunique())
# Out:
# Unique Restaurant Names =  55693

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123657 entries, 0 to 123656
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Restaurant_Name  123657 non-null  object
#  1   Dining_Rating    91421 non-null   float64
#  2   Delivery_Rating  122377 non-null  float64
#  3   Dining Votes     123657 non-null  int64
#  4   Delivery_Votes   123657 non-null  int64
#  5   Cuisine          123657 non-null  object
#  6   Place_Name       123657 non-null  object
#  7   City             123657 non-null  object
#  8   Item_Name        123657 non-null  object
#  9   Best_Seller      27942 non-null   object
#  10  Votes            123657 non-null  int64
#  11  Prices           123657 non-null  float64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 11.3+ MB

# %%
df.describe()
# Out:
#        Dining_Rating  Delivery_Rating   Dining Votes  Delivery_Votes  \
# count   91421.000000    122377.000000  123657.000000   123657.000000
# mean        3.822264         3.963184     152.729858      115.763725
# std         0.408693         0.245900     232.214061      243.970828
# min         2.500000         2.500000       0.000000        0.000000
# 25%         3.600000         3.800000       0.000000        0.000000
# 50%         3.900000         4.000000      30.000000        0.000000
# 75%         4.100000         4.100000     217.000000       23.000000
# max         4.800000         4.600000     997.000000      983.000000
#
#                Votes         Prices
# count  123657.000000  123657.000000
# mean       24.666772     241.378399
# std       125.236009     192.830713
# min         0.000000       0.950000
# 25%         0.000000     130.000000
# 50%         0.000000     208.570000
# 75%        15.000000     299.000000
# max      9750.000000   12024.000000

# %%
df.isna().sum()
# Out:
# Restaurant_Name        0
# Dining_Rating      32236
# Delivery_Rating     1280
# Dining Votes           0
# Delivery_Votes         0
# Cuisine                0
# Place_Name             0
# City                   0
# Item_Name              0
# Best_Seller        95715
# Votes                  0
# Prices                 0
# dtype: int64

# %%
print("Percentage of Best Seller Missing = ", ((df["Best_Seller"].isna().sum()) / len(df))*100)
# Out:
# Percentage of Best Seller Missing =  77.40362454208011

# %%
print("Percentage of Dining Rating Missing = ", ((df["Dining_Rating"].isna().sum()) / len(df))*100)
# Out:
# Percentage of Dining Rating Missing =  26.068884090670156

# %%
print("Percentage of Delivery Rating Missing = ", ((df["Delivery_Rating"].isna().sum()) / len(df))*100)
# Out:
# Percentage of Delivery Rating Missing =  1.0351213437168942

# %%
print("Duplicate Rows = ",df.duplicated().sum())
# Out:
# Duplicate Rows =  22127
